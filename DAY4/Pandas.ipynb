# %% [markdown]
# <a href="https://colab.research.google.com/github/gourynandana/Srishti/blob/main/DAY4/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {"Name": ["harry", "peter", "Chris"],"Marks": [85, 100, 99]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0  harry     85
# 1  peter    100
# 2  Chris     99

# %%
import numpy as np
import pandas as pd
data_dict = {
'Name': ['Ram','harry', 'peter', 'tonny', 'Fexon', 'gautham'],
'Age': [25, np.nan, 30, 22, 28, 28],
'Score': [85, 90, 95, 80, 70, 70]
}
df = pd.DataFrame(data_dict)
print(df)
print("\n")
print("Null values per column:\n", df.isnull().sum())
# Out:
#       Name   Age  Score
# 0      Ram  25.0     85
# 1    harry   NaN     90
# 2    peter  30.0     95
# 3    tonny  22.0     80
# 4    Fexon  28.0     70
# 5  gautham  28.0     70
#
#
# Null values per column:
#  Name     0
# Age      1
# Score    0
# dtype: int64

# %%
import pandas as pd
data = {"Marks": [50, 88, 95, 67]}
df = pd.DataFrame(data)
print("Highest Mark =", df["Marks"].max())
# Out:
# Highest Mark = 95

# %%
import pandas as pd
data = {
    "Name": ["peter", "Harry"],
    "Mark": [80, 90]
}
df = pd.DataFrame(data)
df["Grade"] = ["B", "A"]

print(df)
# Out:
#     Name  Mark Grade
# 0  peter    80     B
# 1  Harry    90     A
